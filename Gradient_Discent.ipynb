# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthik-kudikilla/2216116-AIML/blob/main/Gradient_Discent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Creating a Dataframe
import pandas as pd

#Creating an Empty Dataframe
df=pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#Initialize list Elements
data=[0.2,0.4,0.6,0.8]

df=pd.DataFrame(data,columns=['Bacteria_size'])
df['Max_Growth']=[3.4,3.8,4.2,4.6]
df
# Out:
#    Bacteria_size  Max_Growth
# 0            0.2         3.4
# 1            0.4         3.8
# 2            0.6         4.2
# 3            0.8         4.6

# %%
#splitting the data
x_train = df.iloc[:3,:-1]
y_train = df.iloc[:3,-1:]
x_test = df.iloc[3:,:-1]
y_test = df.iloc[3:,-1:]

# %%
x_train
# Out:
#    Bacteria_size
# 0            0.2
# 1            0.4
# 2            0.6

# %%
import sympy as sym
from sympy import *

# %%
#step1:Initialize model parameters
import sympy as sym
from sympy import *
mi = 1                                                                            
ci = -1
n = 0.01
epochs = 250
iter = 1

ns = len(x_train)
# Step2: Start iteration
for iter in range(1,epochs+1):
  print("Iteration : {}".format(iter))
  print('++++++++++++++++++++++++++++')
  #step3: track samples
  for sample in range(0,ns):
    xa = x_train['Bacteria_size'][sample] #0.2
    ya = y_train['Max_Growth'][sample] #3.4
    print("-->sample {}".format(sample+1)+"x={}".format(xa)+"y={}".format(ya))

    #step 4:Calculate the Gradient
    E = (0.5)*(y-m*x-c)**2 # Gradient Function
    x = sym.Symbol('x')
    y = sym.Symbol('y')
    m = sym.Symbol('m')
    c = sym.Symbol('c')

    deltaE_m = sym.diff(E,m)
    deltaE_c = sym.diff(E,c)

    #substituting values
    deltaE_m=deltaE_m.subs(m,mi)
    deltaE_m=deltaE_m.subs(c,ci)
    deltaE_m=deltaE_m.subs(x,xa)
    deltaE_m=deltaE_m.subs(y,ya)

    deltaE_c=deltaE_c.subs(m,mi)
    deltaE_c=deltaE_c.subs(c,ci)
    deltaE_c=deltaE_c.subs(x,xa)
    deltaE_c=deltaE_c.subs(y,ya)

    print('deltaE_m:',deltaE_m)
    print('deltaE_c',deltaE_c)

    #Step5: Calculate step length
    del_m=-n*deltaE_m
    del_c=-n*deltaE_c

    #step6:Updating model parameters
    mi=mi+del_m
    ci=ci+del_c
    print("m:{}".format(mi))
    print("c:{}".format(ci))

print('++++++++++++++++++++++++++++++++++++++')
print('Optimal Values:')
print("m:{}".format(mi))
print("c:{}".format(ci))
# Out:
# Iteration : 1
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.840000000000000
# deltaE_c -4.20000000000000
# m:1.00840000000000
# c:-0.958000000000000
# -->sample 2x=0.4y=3.8
# deltaE_m: -1.74185600000000
# deltaE_c -4.35464000000000
# m:1.02581856000000
# c:-0.914453600000000
# -->sample 3x=0.6y=4.2
# deltaE_m: -2.69937747840000
# deltaE_c -4.49896246400000
# m:1.05281233478400
# c:-0.869463975360000
# Iteration : 2
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.811780301680640
# deltaE_c -4.05890150840320
# m:1.06093013780081
# c:-0.828874960275968
# -->sample 2x=0.4y=3.8
# deltaE_m: -1.68180116206226
# deltaE_c -4.20450290515565
# m:1.07774814942143
# c:-0.786829931224411
# -->sample 3x=0.6y=4.2
# deltaE_m: -2.60410862494293
# deltaE_c -4.34018104157155
# m:1.10378923567086
# c:-0.743428120808696
# Iteration : 3
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.784534054734905
# deltaE_c -3.92267027367452
# m:1.11163457621821
# c:-0.704201418071951
# -->sample 2x=0.4y=3.8
# deltaE_m: -1.62381903503387
# deltaE_c -4.05954758758467
# m:1.12787276656855
# c:-0.663605942196104
# -->sample 3x=0.6y=4.2
# deltaE_m: -2.51212936935299
# deltaE_c -4.18688228225498
# m:1.15299406026208
# c:-0.621737119373554
# Iteration : 4
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.758227661464228
# deltaE_c -3.79113830732114
# m:1.16057633687672
# c:-0.583825736300343
# -->sample 2x=0.4y=3.8
# deltaE_m: -1.56783808061986
# deltaE_c -3.91959520154966
# m:1.17625471768292
# c:-0.544629784284846
# -->sample 3x=0.6y=4.2
# deltaE_m: -2.42332617220506
# deltaE_c -4.03887695367510
# m:1.20048797940497
# c:-0.504241014748095
# Iteration : 5
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.732828683773420
# deltaE_c -3.66414341886710
# m:1.20781626624270
# c:-0.467599580559424
# -->sample 2x=0.4y=3.8
# deltaE_m: -1.51378922962494
# deltaE_c -3.78447307406234
# m:1.22295415853895
# c:-0.429754849818801
# -->sample 3x=0.6y=4.2
# deltaE_m: -2.33758941281726
# deltaE_c -3.89598235469543
# m:1.24633005266712
# c:-0.390795026271847
# Iteration : 6
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.708305803147684
# deltaE_c -3.54152901573842
# m:1.25341311069860
# c:-0.355379736114462
# -->sample 2x=0.4y=3.8
# deltaE_m: -1.46160579673401
# deltaE_c -3.65401449183502
# m:1.26802916866594
# c:-0.318839591196112
# -->sample 3x=0.6y=4.2
# deltaE_m: -2.25481325399793
# deltaE_c -3.75802208999655
# m:1.29057730120592
# c:-0.281259370296147
# Iteration : 7
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.684628782010993
# deltaE_c -3.42314391005496
# m:1.29742358902603
# c:-0.247027931195597
# -->sample 2x=0.4y=3.8
# deltaE_m: -1.41122339823407
# deltaE_c -3.52805849558519
# m:1.31153582300837
# c:-0.211747346239745
# -->sample 3x=0.6y=4.2
# deltaE_m: -2.17489551146083
# deltaE_c -3.62482585243472
# m:1.33328477812298
# c:-0.175499087715398
# Iteration : 8
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.661768426418160
# deltaE_c -3.30884213209080
# m:1.33990246238716
# c:-0.142410666394490
# -->sample 2x=0.4y=3.8
# deltaE_m: -1.36257987257585
# deltaE_c -3.40644968143963
# m:1.35352826111292
# c:-0.108346169580094
# -->sample 3x=0.6y=4.2
# deltaE_m: -2.09773752774741
# deltaE_c -3.49622921291234
# m:1.37450563639039
# c:-0.0733838774509702
# Iteration : 9
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.639696550034578
# deltaE_c -3.19848275017289
# m:1.38090260189074
# c:-0.0413990499492413
# -->sample 2x=0.4y=3.8
# deltaE_m: -1.31561520367718
# deltaE_c -3.28903800919295
# m:1.39405875392751
# c:-0.00850866985731188
# -->sample 3x=0.6y=4.2
# deltaE_m: -2.02324405050048
# deltaE_c -3.37207341750081
# m:1.41429119443251
# c:0.0252120643176962
# Iteration : 10
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.618385939359160
# deltaE_c -3.09192969679580
# m:1.42047505382611
# c:0.0561313612856542
# -->sample 2x=0.4y=3.8
# deltaE_m: -1.27027144687356
# deltaE_c -3.17567861718390
# m:1.43317776829484
# c:0.0878881474574932
# -->sample 3x=0.6y=4.2
# deltaE_m: -1.95132311493936
# deltaE_c -3.25220519156560
# m:1.45269099944424
# c:0.120410199373149
# Iteration : 11
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.597810320147601
# deltaE_c -2.98905160073800
# m:1.45866910264571
# c:0.150300715380529
# -->sample 2x=0.4y=3.8
# deltaE_m: -1.22649265742447
# deltaE_c -3.06623164356119
# m:1.47093402921996
# c:0.180963031816141
# -->sample 3x=0.6y=4.2
# deltaE_m: -1.88188593039113
# deltaE_c -3.13647655065189
# m:1.48975288852387
# c:0.212327797322660
# Iteration : 12
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.577944324994513
# deltaE_c -2.88972162497257
# m:1.49553233177381
# c:0.241225013572386
# -->sample 2x=0.4y=3.8
# deltaE_m: -1.18422482148724
# deltaE_c -2.96056205371809
# m:1.50737457998869
# c:0.270830634109567
# -->sample 3x=0.6y=4.2
# deltaE_m: -1.81484677073833
# deltaE_c -3.02474461789722
# m:1.52552304769607
# c:0.301078080288539
# Iteration : 13
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.558763462034449
# deltaE_c -2.79381731017225
# m:1.53111068231641
# c:0.329016253390261
# -->sample 2x=0.4y=3.8
# deltaE_m: -1.14341578947327
# deltaE_c -2.85853947368317
# m:1.54254484021115
# c:0.357601648127093
# -->sample 3x=0.6y=4.2
# deltaE_m: -1.75012286864773
# deltaE_c -2.91687144774622
# m:1.56004606889762
# c:0.386770362604555
# Iteration : 14
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.540244084723184
# deltaE_c -2.70122042361592
# m:1.56544850974486
# c:0.413782566840714
# -->sample 2x=0.4y=3.8
# deltaE_m: -1.10401521170454
# deltaE_c -2.76003802926134
# m:1.57648866186190
# c:0.441382947133328
# -->sample 3x=0.6y=4.2
# deltaE_m: -1.68763431344972
# deltaE_c -2.81272385574953
# m:1.59336500499640
# c:0.469510185690823
# Iteration : 15
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.522363362661979
# deltaE_c -2.61181681330990
# m:1.59858863862302
# c:0.495628353823922
# -->sample 2x=0.4y=3.8
# deltaE_m: -1.06597447629075
# deltaE_c -2.66493619072687
# m:1.60924838338593
# c:0.522277715731191
# -->sample 3x=0.6y=4.2
# deltaE_m: -1.62730395254235
# deltaE_c -2.71217325423725
# m:1.62552142291135
# c:0.549399448273563
# Iteration : 16
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.505099253428833
# deltaE_c -2.52549626714417
# m:1.63057241544564
# c:0.574654410945005
# -->sample 2x=0.4y=3.8
# deltaE_m: -1.02924664915070
# deltaE_c -2.57311662287674
# m:1.64086488193714
# c:0.600385577173772
# -->sample 3x=0.6y=4.2
# deltaE_m: -1.56905729619836
# deltaE_c -2.61509549366394
# m:1.65655545489913
# c:0.626536532110412
# Iteration : 17
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.488430475381953
# deltaE_c -2.44215237690976
# m:1.66143975965295
# c:0.650958055879510
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.993786416103725
# deltaE_c -2.48446604025931
# m:1.67137762381398
# c:0.675802716282103
# -->sample 3x=0.6y=4.2
# deltaE_m: -1.51282242565770
# deltaE_c -2.52137070942951
# m:1.68650584807056
# c:0.701016423376398
# Iteration : 18
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.472336481401898
# deltaE_c -2.36168240700949
# m:1.69122921288458
# c:0.724633247446493
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.959550026959870
# deltaE_c -2.39887506739968
# m:1.70082471315418
# c:0.748621998120489
# -->sample 3x=0.6y=4.2
# deltaE_m: -1.45852990439220
# deltaE_c -2.43088317398700
# m:1.71541001219810
# c:0.772930829860359
# Iteration : 19
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.456797433540004
# deltaE_c -2.28398716770002
# m:1.71997798653350
# c:0.795770701537360
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.926495241539696
# deltaE_c -2.31623810384924
# m:1.72924293894890
# c:0.818933082575852
# -->sample 3x=0.6y=4.2
# deltaE_m: -1.40611269243289
# deltaE_c -2.34352115405481
# m:1.74330406587323
# c:0.842368294116400
# Iteration : 20
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.441794178541791
# deltaE_c -2.20897089270895
# m:1.74772200765865
# c:0.864458003043490
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.894581277557221
# deltaE_c -2.23645319389305
# m:1.75666782043422
# c:0.886822534982420
# -->sample 3x=0.6y=4.2
# deltaE_m: -1.35550606365423
# deltaE_c -2.25917677275705
# m:1.77022288107076
# c:0.909414302709991
# Iteration : 21
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.427308224215172
# deltaE_c -2.13654112107586
# m:1.77449596331291
# c:0.930779713920749
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.863768760301634
# deltaE_c -2.15942190075409
# m:1.78313365091593
# c:0.952373932928290
# -->sample 3x=0.6y=4.2
# deltaE_m: -1.30664752591329
# deltaE_c -2.17774587652215
# m:1.79620012617506
# c:0.974151391693512
# Iteration : 22
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.413321716614295
# deltaE_c -2.06660858307148
# m:1.80033334334120
# c:0.994817477524226
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.834019674055717
# deltaE_c -2.08504918513929
# m:1.80867354008176
# c:1.01566796937562
# -->sample 3x=0.6y=4.2
# deltaE_m: -1.25947674394519
# deltaE_c -2.09912790657532
# m:1.82126830752121
# c:1.03665924844137
# Iteration : 23
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.399817418010877
# deltaE_c -1.99908709005439
# m:1.82526648170132
# c:1.05665011934192
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.805297315191022
# deltaE_c -2.01324328797755
# m:1.83331945485323
# c:1.07678255222169
# -->sample 3x=0.6y=4.2
# deltaE_m: -1.21393546491982
# deltaE_c -2.02322577486637
# m:1.84545880950243
# c:1.09701480997036
# Iteration : 24
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.386778685625832
# deltaE_c -1.93389342812916
# m:1.84932659635869
# c:1.11635374425165
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.777566246881951
# deltaE_c -1.94391561720488
# m:1.85710225882751
# c:1.13579290042370
# -->sample 3x=0.6y=4.2
# deltaE_m: -1.16996744656788
# deltaE_c -1.94994574427980
# m:1.86880193329319
# c:1.15529235786649
# Iteration : 25
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.374189451094974
# deltaE_c -1.87094725547487
# m:1.87254382780414
# c:1.17400183042124
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.750792255382841
# deltaE_c -1.87698063845710
# m:1.88005175035796
# c:1.19277163680581
# -->sample 3x=0.6y=4.2
# deltaE_m: -1.12751838778764
# deltaE_c -1.87919731297941
# m:1.89132693423584
# c:1.21156360993561
# Iteration : 26
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.362034200643445
# deltaE_c -1.81017100321722
# m:1.89494727624227
# c:1.22966531996778
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.724942307814124
# deltaE_c -1.81235576953531
# m:1.90219669932042
# c:1.24778887766313
# -->sample 3x=0.6y=4.2
# deltaE_m: -1.08653586164677
# deltaE_c -1.81089310274462
# m:1.91306205793688
# c:1.26589780869058
# Iteration : 27
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.350297955944409
# deltaE_c -1.75148977972204
# m:1.91656503749633
# c:1.28341270648780
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.699984511405468
# deltaE_c -1.74996127851367
# m:1.92356488261038
# c:1.30091231927294
# -->sample 3x=0.6y=4.2
# deltaE_m: -1.04696925069650
# deltaE_c -1.74494875116083
# m:1.93403457511735
# c:1.31836180678454
# Iteration : 28
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.338966255638397
# deltaE_c -1.69483127819199
# m:1.93742423767373
# c:1.33531011956646
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.675888074145617
# deltaE_c -1.68972018536404
# m:1.94418311841519
# c:1.35220732142011
# -->sample 3x=0.6y=4.2
# deltaE_m: -1.00876968451847
# deltaE_c -1.68128280753078
# m:1.95427081526037
# c:1.36902014949541
# Iteration : 29
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.328025137490502
# deltaE_c -1.64012568745251
# m:1.95755106663528
# c:1.38542140636994
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.652623266790380
# deltaE_c -1.63155816697595
# m:1.96407729930318
# c:1.40173698803970
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.971889979427036
# deltaE_c -1.61981663237839
# m:1.97379619909745
# c:1.41793515436348
# Iteration : 30
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.317461121163406
# deltaE_c -1.58730560581703
# m:1.97697081030909
# c:1.43380821042165
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.630161386181885
# deltaE_c -1.57540346545471
# m:1.98327242417090
# c:1.44956224507620
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.936284580252755
# deltaE_c -1.56047430042126
# m:1.99263526997343
# c:1.46516698808041
# Iteration : 31
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.307261191584980
# deltaE_c -1.53630595792490
# m:1.99570788188928
# c:1.48053004765966
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.608474719833850
# deltaE_c -1.52118679958463
# m:2.00179262908762
# c:1.49574191565551
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.901909504135153
# deltaE_c -1.50318250689192
# m:2.01081172412897
# c:1.51077374072443
# Iteration : 32
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.297412782889956
# deltaE_c -1.48706391444978
# m:2.01378585195787
# c:1.52564437986892
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.587536511739171
# deltaE_c -1.46884127934793
# m:2.01966121707526
# c:1.54033279266240
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.868722286255464
# deltaE_c -1.44787047709244
# m:2.02834843993782
# c:1.55481149743333
# Iteration : 33
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.287903762915822
# deltaE_c -1.43951881457911
# m:2.03122747756698
# c:1.56920668557912
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.567320929357636
# deltaE_c -1.41830232339409
# m:2.03690068686055
# c:1.58338970881306
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.836681927442365
# deltaE_c -1.39446987907061
# m:2.04526750613498
# c:1.59733440760377
# Iteration : 34
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.278722418233848
# deltaE_c -1.39361209116924
# m:2.04805473031731
# c:1.61127052851546
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.547803031743046
# deltaE_c -1.36950757935762
# m:2.05353276063474
# c:1.62496560430903
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.805748843586072
# deltaE_c -1.34291473931012
# m:2.06159024907061
# c:1.63839475170214
# Iteration : 35
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.269857439696749
# deltaE_c -1.34928719848374
# m:2.06428882346757
# c:1.65188762368697
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.528958738770399
# deltaE_c -1.32239684692600
# m:2.06957841085528
# c:1.66511159215623
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.775884816798361
# deltaE_c -1.29314136133060
# m:2.07733725902326
# c:1.67804300576954
# Iteration : 36
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.261297908485162
# deltaE_c -1.30648954242581
# m:2.07995023810811
# c:1.69110790119380
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.510764801425183
# deltaE_c -1.27691200356296
# m:2.08505788612236
# c:1.70387702122943
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.747052948258293
# deltaE_c -1.24508824709716
# m:2.09252841560495
# c:1.71632790370040
# Iteration : 37
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.253033282635723
# deltaE_c -1.26516641317861
# m:2.09505874843130
# c:1.72897956783218
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.493198773118118
# deltaE_c -1.23299693279529
# m:2.09999073616249
# c:1.74130953716014
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.719217612685423
# deltaE_c -1.19869602114237
# m:2.10718291228934
# c:1.75329649737156
# Iteration : 38
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.245053384034114
# deltaE_c -1.22526692017057
# m:2.10963344612968
# c:1.76554916657327
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.476238981989944
# deltaE_c -1.19059745497486
# m:2.11439583594958
# c:1.77745514112302
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.692344414384342
# deltaE_c -1.15390735730724
# m:2.12131928009342
# c:1.78899421469609
# Iteration : 39
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.237348385857046
# deltaE_c -1.18674192928523
# m:2.12369276395199
# c:1.80086163398894
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.459864504172105
# deltaE_c -1.14966126043026
# m:2.12829140899372
# c:1.81235824659324
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.666400144806317
# deltaE_c -1.11066690801053
# m:2.13495541044178
# c:1.82346491567335
# Iteration : 40
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.229908800447659
# deltaE_c -1.14954400223830
# m:2.13725449844625
# c:1.83496035569573
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.444055137970307
# deltaE_c -1.11013784492577
# m:2.14169504982596
# c:1.84606173414499
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.641352741575662
# deltaE_c -1.06892123595944
# m:2.14810857724171
# c:1.85675094650458
# Iteration : 41
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.222725467609415
# deltaE_c -1.11362733804707
# m:2.15033583191781
# c:1.86788721988505
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.428791378939129
# deltaE_c -1.07197844734782
# m:2.15462374570720
# c:1.87860700435853
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.617171248930289
# deltaE_c -1.02861874821715
# m:2.16079545819650
# c:1.88889319184070
# Iteration : 42
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.215789543303999
# deltaE_c -1.07894771652000
# m:2.16295335362954
# c:1.89968266900590
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.414054395816912
# deltaE_c -1.03513598954228
# m:2.16709389758771
# c:1.91003402890133
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.593825779527628
# deltaE_c -0.989709632546047
# m:2.17303215538299
# c:1.91993112522679
# Iteration : 43
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.209092488739323
# deltaE_c -1.04546244369662
# m:2.17512308027038
# c:1.93038574966375
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.399826007291238
# deltaE_c -0.999565018228095
# m:2.17912134034329
# c:1.94038139984603
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.571287477568794
# deltaE_c -0.952145795947990
# m:2.18483421511898
# c:1.94990285780551
# Iteration : 44
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.202626059834138
# deltaE_c -1.01313029917069
# m:2.18686047571732
# c:1.96003416079722
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.386088659566340
# deltaE_c -0.965221648915850
# m:2.19072136231299
# c:1.96968637728638
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.549528483195497
# deltaE_c -0.915880805325829
# m:2.19621664714494
# c:1.97884518533964
# Iteration : 45
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.196382297046275
# deltaE_c -0.981911485231374
# m:2.19818047011540
# c:1.98866430019195
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.372825404704755
# deltaE_c -0.932063511761887
# m:2.20190872416245
# c:1.99798493530957
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.528521898115775
# deltaE_c -0.880869830192959
# m:2.20719394314361
# c:2.00679363361150
# Iteration : 46
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.190353515551956
# deltaE_c -0.951767577759778
# m:2.20909747829913
# c:2.01631130938910
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.360019879716500
# deltaE_c -0.900049699291251
# m:2.21269767709629
# c:2.02531180638201
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.508241752416128
# deltaE_c -0.847069587360214
# m:2.21778009462046
# c:2.03378250225561
# Iteration : 47
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.184532295764059
# deltaE_c -0.922661478820296
# m:2.21962541757810
# c:2.04300911704382
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.347656286369979
# deltaE_c -0.869140715924946
# m:2.22310198044180
# c:2.05170052420306
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.488662972519115
# deltaE_c -0.814438287531858
# m:2.22798861016699
# c:2.05984490707838
# Iteration : 48
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.178911474177644
# deltaE_c -0.894557370888219
# m:2.22977772490876
# c:2.06879048078727
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.335719371699691
# deltaE_c -0.839298429249228
# m:2.23313491862576
# c:2.07718346507976
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.469761350246872
# deltaE_c -0.782935583744786
# m:2.23783253212823
# c:2.08501282091721
# Iteration : 49
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.173484134531430
# deltaE_c -0.867420672657148
# m:2.23956737347354
# c:2.09368702764378
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.324194409186722
# deltaE_c -0.810486022966805
# m:2.24280931756541
# c:2.10179188787345
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.451513512952385
# deltaE_c -0.752522521587308
# m:2.24732445269493
# c:2.10931711308932
# Iteration : 50
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.168243599274339
# deltaE_c -0.841217996371694
# m:2.24900688868768
# c:2.11772929305304
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.313067180588757
# deltaE_c -0.782667951471893
# m:2.25213756049357
# c:2.12555597256775
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.433896894681664
# deltaE_c -0.723161491136106
# m:2.25647652944038
# c:2.13278758747912
# Iteration : 51
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.163183421326562
# deltaE_c -0.815917106632808
# m:2.25810836365365
# c:2.14094675854544
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.302323958397239
# deltaE_c -0.755809895993097
# m:2.26113160323762
# c:2.14850485750537
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.416889708331232
# deltaE_c -0.694816180552053
# m:2.26530050032093
# c:2.15545301931090
# Iteration : 52
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.158297376124984
# deltaE_c -0.791486880624918
# m:2.26688347408218
# c:2.16336788811714
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.291951488899993
# deltaE_c -0.729878722249982
# m:2.26980298897118
# c:2.17066667533964
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.400470918766588
# deltaE_c -0.667451531277647
# m:2.27380769815885
# c:2.17734119065242
# Iteration : 53
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.153579453943162
# deltaE_c -0.767897269715810
# m:2.27534349269828
# c:2.18502016334958
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.281936975828444
# deltaE_c -0.704842439571109
# m:2.27816286245656
# c:2.19206858774529
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.384620216868463
# deltaE_c -0.641033694780772
# m:2.28200906462525
# c:2.19847892469310
# Iteration : 54
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.149023852476371
# deltaE_c -0.745119262381853
# m:2.28349930315001
# c:2.20593011731692
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.272268064569232
# deltaE_c -0.680670161423079
# m:2.28622198379571
# c:2.21273681893115
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.369317994474859
# deltaE_c -0.615529990791431
# m:2.28991516374045
# c:2.21889211883906
# Iteration : 55
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.144624969682570
# deltaE_c -0.723124848412848
# m:2.29136141343728
# c:2.22612336732319
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.262932826920760
# deltaE_c -0.657332067301899
# m:2.29399074170649
# c:2.23269668799621
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.354545320187940
# deltaE_c -0.590908866979900
# m:2.29753619490837
# c:2.23860577666601
# Iteration : 56
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.140377396870464
# deltaE_c -0.701886984352319
# m:2.29893996887707
# c:2.24562464650953
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.253919746375856
# deltaE_c -0.634799365939641
# m:2.30147916634083
# c:2.25197264016893
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.340283916015945
# deltaE_c -0.567139860026575
# m:2.30488200550099
# c:2.25764403876919
# Iteration : 57
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.136275912026122
# deltaE_c -0.681379560130609
# m:2.30624476462125
# c:2.26445783437050
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.245217703912400
# deltaE_c -0.613044259781001
# m:2.30869694166037
# c:2.27058827696831
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.326516134821280
# deltaE_c -0.544193558035467
# m:2.31196210300859
# c:2.27603021254866
# Iteration : 58
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.132315473369924
# deltaE_c -0.661577366849619
# m:2.31328525774229
# c:2.28264598621716
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.236815964274370
# deltaE_c -0.592039910685926
# m:2.31565341738503
# c:2.28856638532402
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.313224938546978
# deltaE_c -0.522041564244963
# m:2.31878566677050
# c:2.29378680096647
# Iteration : 59
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.128491213135886
# deltaE_c -0.642456065679431
# m:2.32007057890186
# c:2.30021136162326
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.228704162726397
# deltaE_c -0.571760406815993
# m:2.32235762052912
# c:2.30592896569142
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.300393877194662
# deltaE_c -0.500656461991103
# m:2.32536155930107
# c:2.31093553031133
# Iteration : 60
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.124798431565690
# deltaE_c -0.623992157828452
# m:2.32660954361673
# c:2.31717545188962
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.220872292265476
# deltaE_c -0.552180730663690
# m:2.32881826653938
# c:2.32269725919626
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.288007068528069
# deltaE_c -0.480011780880116
# m:2.33169833722466
# c:2.32749737700506
# Iteration : 61
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.121232591110002
# deltaE_c -0.606162955550011
# m:2.33291066313576
# c:2.33355900656056
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.213310691274055
# deltaE_c -0.533276728185138
# m:2.33504377004850
# c:2.33889177384241
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.276049178477094
# deltaE_c -0.460081964128491
# m:2.33780426183327
# c:2.34349259348369
# Iteration : 62
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.117789310829930
# deltaE_c -0.588946554149651
# m:2.33898215494157
# c:2.34938205902519
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.206010031599272
# deltaE_c -0.515025078998181
# m:2.34104225525757
# c:2.35453230981517
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.264505402218173
# deltaE_c -0.440842337030289
# m:2.34368730927975
# c:2.35894073318548
# Iteration : 63
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.114464360991715
# deltaE_c -0.572321804958575
# m:2.34483195288966
# c:2.36466395123506
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.198961307043630
# deltaE_c -0.497403267609074
# m:2.34682156596010
# c:2.36963798391115
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.253361445907673
# deltaE_c -0.422269076512789
# m:2.34935518041918
# c:2.37386067467628
# Iteration : 64
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.111253657847977
# deltaE_c -0.556268289239886
# m:2.35046771699766
# c:2.37942335756868
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.192155822252904
# deltaE_c -0.480389555632259
# m:2.35238927522019
# c:2.38422725312500
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.242603509045733
# deltaE_c -0.404339181742889
# m:2.35481531031064
# c:2.38827064494243
# Iteration : 65
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.108153258599088
# deltaE_c -0.540766292995442
# m:2.35589684289663
# c:2.39367830787238
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.185585181987585
# deltaE_c -0.463962954968962
# m:2.35775269471651
# c:2.39831793742207
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.232218267448812
# deltaE_c -0.387030445748021
# m:2.36007487739100
# c:2.40218824187955
# Iteration : 66
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.105159356528449
# deltaE_c -0.525796782642246
# m:2.36112647095628
# c:2.40744620970598
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.179241280764604
# deltaE_c -0.448103201911511
# m:2.36291888376393
# c:2.41192724172509
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.222192856809931
# deltaE_c -0.370321428016552
# m:2.36514081233203
# c:2.41563045600526
# Iteration : 67
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.102268276305668
# deltaE_c -0.511341381528338
# m:2.36616349509508
# c:2.42074386982054
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.173116292856570
# deltaE_c -0.432790732141426
# m:2.36789465802365
# c:2.42507177714195
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.212514856826314
# deltaE_c -0.354191428043856
# m:2.37001980659191
# c:2.42861369142239
# Iteration : 68
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0994764694518449
# deltaE_c -0.497382347259224
# m:2.37101457128643
# c:2.43358751489499
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.167202662636177
# deltaE_c -0.418006656590442
# m:2.37268659791279
# c:2.43776758146089
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.203172275874861
# deltaE_c -0.338620459791435
# m:2.37471832067154
# c:2.44115378605880
# Iteration : 69
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0967805099613774
# deltaE_c -0.483902549806887
# m:2.37568612577115
# c:2.44599281155687
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.161493095253866
# deltaE_c -0.403732738134664
# m:2.37730105672369
# c:2.45003013893822
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.194153536216538
# deltaE_c -0.323589227027564
# m:2.37924259208586
# c:2.45326603120850
# Iteration : 70
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0941770900748664
# deltaE_c -0.470885450374332
# m:2.38018436298661
# c:2.45797488571224
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.155980547637247
# deltaE_c -0.389951369093118
# m:2.38174416846298
# c:2.46187439940317
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.185447459711425
# deltaE_c -0.309079099519042
# m:2.38359864306009
# c:2.46496519039836
# Iteration : 71
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0916630161979241
# deltaE_c -0.458315080989620
# m:2.38451527322207
# c:2.46954834120826
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.150658219801165
# deltaE_c -0.376645549502913
# m:2.38602185542008
# c:2.47331479670329
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.177043254026798
# deltaE_c -0.295072090044663
# m:2.38779228796035
# c:2.47626551760373
# Iteration : 72
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0892352049608394
# deltaE_c -0.446176024804196
# m:2.38868464000996
# c:2.48072727785177
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.145519546457696
# deltaE_c -0.363798866144240
# m:2.39013983547454
# c:2.48436526651322
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.168930499321236
# deltaE_c -0.281550832202060
# m:2.39182914046775
# c:2.48718077483524
# Iteration : 73
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0868906794142424
# deltaE_c -0.434453397071212
# m:2.39269804726189
# c:2.49152530880595
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.140558188915717
# deltaE_c -0.351395472289293
# m:2.39410362915105
# c:2.49503926352884
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.161099135388316
# deltaE_c -0.268498558980527
# m:2.39571462050493
# c:2.49772424911865
# Iteration : 74
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0846265653560730
# deltaE_c -0.423132826780365
# m:2.39656088615849
# c:2.50195557738645
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.135768027260060
# deltaE_c -0.339420068150150
# m:2.39791856643109
# c:2.50534977806795
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.153539449244034
# deltaE_c -0.255899082073390
# m:2.39945396092354
# c:2.50790876888869
# Iteration : 75
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0824400877853213
# deltaE_c -0.412200438926606
# m:2.40027836180139
# c:2.51203077327795
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.131143152800596
# deltaE_c -0.327857882001491
# m:2.40158979332939
# c:2.51530935209797
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.146242063142637
# deltaE_c -0.243736771904396
# m:2.40305221396082
# c:2.51774671981701
# Iteration : 76
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0803285674781647
# deltaE_c -0.401642837390824
# m:2.40385549963560
# c:2.52176314819092
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.126677860781935
# deltaE_c -0.316694651954839
# m:2.40512227824342
# c:2.52493009471047
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.139197923006087
# deltaE_c -0.231996538343479
# m:2.40651425747348
# c:2.52725006009390
# Iteration : 77
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0782894176822800
# deltaE_c -0.391447088411400
# m:2.40729715165031
# c:2.53116453097802
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.122366643344744
# deltaE_c -0.305916608361860
# m:2.40852081808375
# c:2.53422369706164
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.132398287252868
# deltaE_c -0.220663812088112
# m:2.40984480095628
# c:2.53643033518252
# Iteration : 78
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0763201409252452
# deltaE_c -0.381600704626226
# m:2.41060800236553
# c:2.54024634222878
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.118204182730003
# deltaE_c -0.295510456825006
# m:2.41179004419283
# c:2.54320144679703
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.125834716012362
# deltaE_c -0.209724526687270
# m:2.41304839135296
# c:2.54529869206390
# Iteration : 79
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0744183259331012
# deltaE_c -0.372091629665506
# m:2.41379257461229
# c:2.54901960836056
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.114185344717811
# deltaE_c -0.285463361794527
# m:2.41493442805947
# c:2.55187424197850
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.119499060711490
# deltaE_c -0.199165101185817
# m:2.41612941866658
# c:2.55386589299036
# Iteration : 80
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0725816446552646
# deltaE_c -0.362908223276323
# m:2.41685523511313
# c:2.55749497522312
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.110305172292649
# deltaE_c -0.275762930731622
# m:2.41795828683606
# c:2.56025260453044
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.113383454020754
# deltaE_c -0.188972423367923
# m:2.41909212137627
# c:2.56214232876412
# Iteration : 81
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0708078493921253
# deltaE_c -0.354039246960626
# m:2.41980019987019
# c:2.56568272123373
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.106558879527279
# deltaE_c -0.266397198818198
# m:2.42086578866546
# c:2.56834669322191
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.107480300147289
# deltaE_c -0.179133833578815
# m:2.42194059166694
# c:2.57013803155770
# Iteration : 82
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0690947700217833
# deltaE_c -0.345473850108917
# m:2.42263153936715
# c:2.57359277005879
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.102941845677741
# deltaE_c -0.257354614194353
# m:2.42366095782393
# c:2.57616631620073
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.101782265462948
# deltaE_c -0.169637109104912
# m:2.42467878047856
# c:2.57786268729178
# Iteration : 83
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0674403113225021
# deltaE_c -0.337201556612510
# m:2.42535318359179
# c:2.58123470285790
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0994496094821531
# deltaE_c -0.248624023705383
# m:2.42634767968661
# c:2.58372094309496
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.0962822694558474
# deltaE_c -0.160470449093079
# m:2.42731050238117
# c:2.58532564758589
# Iteration : 84
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0658424503875759
# deltaE_c -0.329212251937879
# m:2.42796892688504
# c:2.58861777010527
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0960778636562867
# deltaE_c -0.240194659140717
# m:2.42892970552160
# c:2.59101971669667
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.0909734759942187
# deltaE_c -0.151622459990365
# m:2.42983944028155
# c:2.59253594129658
# Iteration : 85
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0642992341294226
# deltaE_c -0.321496170647113
# m:2.43048243262284
# c:2.59575090300305
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0928224495791261
# deltaE_c -0.232056123947815
# m:2.43141065711863
# c:2.59807146424253
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.0858492848917765
# deltaE_c -0.143082141486294
# m:2.43226914996755
# c:2.59950228565739
# Iteration : 86
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0628087768698201
# deltaE_c -0.314043884349100
# m:2.43289723773625
# c:2.60264272450088
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0896793521618480
# deltaE_c -0.224198380404620
# m:2.43379403125787
# c:2.60488470830493
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.0809033237642125
# deltaE_c -0.134838872940354
# m:2.43460306449551
# c:2.60623309703433
# Iteration : 87
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0613692580133136
# deltaE_c -0.306846290066568
# m:2.43521675707564
# c:2.60930155993500
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0866446948938988
# deltaE_c -0.216611737234747
# m:2.43608320402458
# c:2.61146767730734
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.0761294401667452
# deltaE_c -0.126882400277909
# m:2.43684449842625
# c:2.61273650131012
# Iteration : 88
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0599789198009256
# deltaE_c -0.299894599004628
# m:2.43744428762426
# c:2.61573544730017
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0837147350600513
# deltaE_c -0.209286837650128
# m:2.43828143497486
# c:2.61782831567667
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.0715216940030494
# deltaE_c -0.119202823338416
# m:2.43899665191489
# c:2.61902034391005
# Iteration : 89
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0586360651413937
# deltaE_c -0.293180325706969
# m:2.43958301256630
# c:2.62195214716712
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0808858591225423
# deltaE_c -0.202214647806356
# m:2.44039187115753
# c:2.62397429364519
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.0670743501961781
# deltaE_c -0.111790583660297
# m:2.44106261465949
# c:2.62509219948179
# Iteration : 90
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0573390555172625
# deltaE_c -0.286695277586313
# m:2.44163600521466
# c:2.62795915225765
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0781545782625928
# deltaE_c -0.195386445656482
# m:2.44241755099729
# c:2.62991301671422
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.0627818716124455
# deltaE_c -0.104636452687410
# m:2.44304536971341
# c:2.63095938124109
# Iteration : 91
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0560863089632452
# deltaE_c -0.280431544816226
# m:2.44360623280304
# c:2.63376369668925
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0755175240758112
# deltaE_c -0.188793810189528
# m:2.44436140804380
# c:2.63565163479115
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.0586389122295419
# deltaE_c -0.0977315203825695
# m:2.44494779716610
# c:2.63662894999497
# Iteration : 92
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0548762981143611
# deltaE_c -0.274381490571805
# m:2.44549656014724
# c:2.63937276490069
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0729714444161640
# deltaE_c -0.182428611040410
# m:2.44622627459140
# c:2.64119705101110
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.0546403105404365
# deltaE_c -0.0910671842340607
# m:2.44677267769681
# c:2.64210772285344
# Iteration : 93
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0537075483214401
# deltaE_c -0.268537741607200
# m:2.44730975318002
# c:2.64479310026951
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0705131993833923
# deltaE_c -0.176282998458481
# m:2.44801488517386
# c:2.64655593025409
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.0507810831849547
# deltaE_c -0.0846351386415911
# m:2.44852269600571
# c:2.64740228164051
# Iteration : 94
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0525786358316696
# deltaE_c -0.262893179158348
# m:2.44904848236402
# c:2.65003121343209
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0681397574489184
# deltaE_c -0.170349393622296
# m:2.44972987993851
# c:2.65173470736832
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.0470564188011449
# deltaE_c -0.0784273646685749
# m:2.45020044412652
# c:2.65251898101500
# Iteration : 95
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0514881860319384
# deltaE_c -0.257440930159692
# m:2.45071532598684
# c:2.65509339031660
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0658481917154650
# deltaE_c -0.164620479288662
# m:2.45137380790400
# c:2.65673959510949
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.0434616720888688
# deltaE_c -0.0724361201481143
# m:2.45180842462489
# c:2.65746395631097
# Iteration : 96
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0504348717528109
# deltaE_c -0.252174358764055
# m:2.45231277334241
# c:2.65998569989861
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0636356763057702
# deltaE_c -0.159089190764425
# m:2.45294913010547
# c:2.66157659180625
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.0399923580782784
# deltaE_c -0.0666539301304638
# m:2.45334905368626
# c:2.66224313110756
# Iteration : 97
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0494174116310382
# deltaE_c -0.247087058155191
# m:2.45384322780257
# c:2.66471400168911
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0614994828759454
# deltaE_c -0.153748707189864
# m:2.45445822263133
# c:2.66625148876101
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.0366441465961178
# deltaE_c -0.0610735776601965
# m:2.45482466409729
# c:2.66686222453761
# Iteration : 98
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0484345685285865
# deltaE_c -0.242172842642932
# m:2.45530900978257
# c:2.66928395296404
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0594369772491725
# deltaE_c -0.148592443122931
# m:2.45590337955506
# c:2.67076987739527
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.0334128569230154
# deltaE_c -0.0556880948716927
# m:2.45623750812429
# c:2.67132675834399
# Iteration : 99
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0474851480062309
# deltaE_c -0.237425740031155
# m:2.45671235960436
# c:2.67370101574430
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0574456161655839
# deltaE_c -0.143614040413960
# m:2.45728681576601
# c:2.67513715614844
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.0302944526351734
# deltaE_c -0.0504907543919559
# m:2.45758976029236
# c:2.67564206369236
# Iteration : 100
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0465679968498341
# deltaE_c -0.232839984249170
# m:2.45805544026086
# c:2.67797046353485
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0555229441443226
# deltaE_c -0.138807360360806
# m:2.45861066970231
# c:2.67935853713846
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.0272850366240962
# deltaE_c -0.0454750610401602
# m:2.45888352006855
# c:2.67981328774886
# Iteration : 101
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0456820016474865
# deltaE_c -0.228410008237432
# m:2.45934034008502
# c:2.68209738783123
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0536665904539035
# deltaE_c -0.134166476134759
# m:2.45987700598956
# c:2.68343905259258
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.0243808462882105
# deltaE_c -0.0406347438136843
# m:2.46012081445244
# c:2.68384540003072
# Iteration : 102
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0448260874157589
# deltaE_c -0.224130437078794
# m:2.46056907532660
# c:2.68608670440151
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0518742661871419
# deltaE_c -0.129685665467855
# m:2.46108781798847
# c:2.68738356105618
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.0215782488904406
# deltaE_c -0.0359637481507340
# m:2.46130360047738
# c:2.68774319853769
# Iteration : 103
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0439992162733668
# deltaE_c -0.219996081366834
# m:2.46174359264011
# c:2.68994315935136
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0501437614370388
# deltaE_c -0.125359403592597
# m:2.46224503025448
# c:2.69119675338729
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.0188737370760164
# deltaE_c -0.0314562284600273
# m:2.46243376762524
# c:2.69151131567189
# Iteration : 104
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0432003861606133
# deltaE_c -0.216001930803067
# m:2.46286577148685
# c:2.69367133497992
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0484729425701382
# deltaE_c -0.121182356425345
# m:2.46335050091255
# c:2.69488315854417
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.0162639245449818
# deltaE_c -0.0271065409083029
# m:2.46351314015800
# c:2.69515422395325
# Iteration : 105
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0424286296030296
# deltaE_c -0.212143148015148
# m:2.46393742645403
# c:2.69727565543340
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0468597495939940
# deltaE_c -0.117149373984985
# m:2.46440602394997
# c:2.69844714917325
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.0137455418740600
# deltaE_c -0.0229092364567665
# m:2.46454347936871
# c:2.69867624153782
# Iteration : 106
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0416830125176875
# deltaE_c -0.208415062588437
# m:2.46496030949388
# c:2.70076039216371
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0453021936154960
# deltaE_c -0.113255484038740
# m:2.46541333143004
# c:2.70189294700409
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.0113154324827303
# deltaE_c -0.0188590541378835
# m:2.46552648575487
# c:2.70208153754547
# Iteration : 107
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0409626330607109
# deltaE_c -0.204813165303555
# m:2.46593611208547
# c:2.70412966919851
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0437983543869211
# deltaE_c -0.109495885967303
# m:2.46637409562934
# c:2.70522462805818
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.00897054873852809
# deltaE_c -0.0149509145642135
# m:2.46646380111673
# c:2.70537413720382
# Iteration : 108
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0402666205145663
# deltaE_c -0.201333102572832
# m:2.46686646732187
# c:2.70738746822955
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0423463779366797
# deltaE_c -0.105865944841699
# m:2.46728993110124
# c:2.70844612767797
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.00670794819677223
# deltaE_c -0.0111799136612873
# m:2.46735701058321
# c:2.70855792681458
# Iteration : 109
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0395941342137555
# deltaE_c -0.197970671068777
# m:2.46775295192535
# c:2.71053763352527
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0409444742818370
# deltaE_c -0.102361185704592
# m:2.46816239666817
# c:2.71156124538231
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.00452478997007200
# deltaE_c -0.00754131661678681
# m:2.46820764456787
# c:2.71163665854848
# Iteration : 110
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0389443625075889
# deltaE_c -0.194721812537944
# m:2.46859708819294
# c:2.71358387667386
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0395909152195846
# deltaE_c -0.0989772880489612
# m:2.46899299734514
# c:2.71457364955435
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.00241833122313961
# deltaE_c -0.00403055203856617
# m:2.46901718065737
# c:2.71461395507474
# Iteration : 111
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0383165217587579
# deltaE_c -0.191582608793789
# m:2.46940034587496
# c:2.71652978116267
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0382840321949369
# deltaE_c -0.0957100804873421
# m:2.46978318619691
# c:2.71748688196755
# -->sample 3x=0.6y=4.2
# deltaE_m: -0.000385923788584819
# deltaE_c -0.000643206314308031
# m:2.46978704543479
# c:2.71749331403069
# Iteration : 112
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0377098553764700
# deltaE_c -0.188549276882350
# m:2.47016414398856
# c:2.71937880679952
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0370222142420249
# deltaE_c -0.0925555356050620
# m:2.47053436613098
# c:2.72030436215557
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.00157498910049103
# deltaE_c 0.00262498183415172
# m:2.47051861623997
# c:2.72027811233722
# Iteration : 113
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0371236328829564
# deltaE_c -0.185618164414782
# m:2.47088985256880
# c:2.72213429398137
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0358039059964430
# deltaE_c -0.0895097649911074
# m:2.47124789162877
# c:2.72302939163128
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.00346687596512574
# deltaE_c 0.00577812660854260
# m:2.47121322286912
# c:2.72297161036520
# Iteration : 114
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0365571490121960
# deltaE_c -0.182785745060980
# m:2.47157879435924
# c:2.72479946781581
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0346276057761992
# deltaE_c -0.0865690144404980
# m:2.47192507041700
# c:2.72566515796021
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.00529212012624658
# deltaE_c 0.00882020021041097
# m:2.47187214921574
# c:2.72557695595811
# Iteration : 115
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0360097228397490
# deltaE_c -0.180048614198745
# m:2.47223224644413
# c:2.72737744210009
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0334918637289006
# deltaE_c -0.0837296593222514
# m:2.47256716508142
# c:2.72821473869332
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.00705302264530250
# deltaE_c 0.0117550377421711
# m:2.47249663485497
# c:2.72809718831590
# Iteration : 116
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0354806969426220
# deltaE_c -0.177403484713110
# m:2.47285144182440
# c:2.72987122316303
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0323952800428857
# deltaE_c -0.0809882001072144
# m:2.47317539462483
# c:2.73068110516410
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.00875180516339658
# deltaE_c 0.0145863419389940
# m:2.47308787657319
# c:2.73053524174471
# Iteration : 117
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0349694365881306
# deltaE_c -0.174847182940653
# m:2.47343757093907
# c:2.73228371357412
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0313365032201021
# deltaE_c -0.0783412580502549
# m:2.47375093597127
# c:2.73306712615462
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0103906126424294
# deltaE_c 0.0173176877373820
# m:2.47364702984485
# c:2.73289394927724
# Iteration : 118
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0344753289507572
# deltaE_c -0.172376644753786
# m:2.47399178313436
# c:2.73461771572478
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0303142284085900
# deltaE_c -0.0757855710214748
# m:2.47429492541844
# c:2.73537557143500
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0119715160116378
# deltaE_c 0.0199525266860627
# m:2.47417521025833
# c:2.73517604616814
# Iteration : 119
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0339977823560397
# deltaE_c -0.169988911780198
# m:2.47451518808189
# c:2.73687593528594
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0293271957925225
# deltaE_c -0.0733179894813065
# m:2.47480846003981
# c:2.73760911518075
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0134965147227835
# deltaE_c 0.0224941912046388
# m:2.47467349489258
# c:2.73738417326871
# Iteration : 120
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0335362255505556
# deltaE_c -0.167681127752778
# m:2.47500885714809
# c:2.73906098454623
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0283741890378124
# deltaE_c -0.0709354725945310
# m:2.47529259903847
# c:2.73977033927218
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0149675392171549
# deltaE_c 0.0249458986952584
# m:2.47514292364630
# c:2.73952088028523
# Iteration : 121
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0330901069971031
# deltaE_c -0.165450534985515
# m:2.47547382471627
# c:2.74117538563508
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.0274540337913649
# deltaE_c -0.0686350844784123
# m:2.47574836505418
# c:2.74186173647986
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0163864533074243
# deltaE_c 0.0273107555123735
# m:2.47558450052111
# c:2.74158862892474
# Iteration : 122
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# ...
# deltaE_m: -0.00273181388210419
# deltaE_c -0.00682953470526027
# m:2.46713086736186
# c:2.80639734095258
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0520055168218154
# deltaE_c 0.0866758613696925
# m:2.46661081219364
# c:2.80553058233888
# Iteration : 212
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0202294510444785
# deltaE_c -0.101147255222392
# m:2.46681310670409
# c:2.80654205489110
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00269308097090470
# deltaE_c -0.00673270242726165
# m:2.46684003751380
# c:2.80660938191538
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0520280426541921
# deltaE_c 0.0867134044236533
# m:2.46631975708725
# c:2.80574224787114
# Iteration : 213
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0201987601422819
# deltaE_c -0.100993800711410
# m:2.46652174468868
# c:2.80675218587825
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00265564649851013
# deltaE_c -0.00663911624627556
# m:2.46654830115366
# c:2.80681857704072
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0520485346397486
# deltaE_c 0.0867475577329140
# m:2.46602781580726
# c:2.80595110146339
# Iteration : 214
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0201686670750320
# deltaE_c -0.100843335375159
# m:2.46622950247801
# c:2.80695953481714
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00261946567666205
# deltaE_c -0.00654866419165501
# m:2.46625569713478
# c:2.80702502145906
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0520670638439547
# deltaE_c 0.0867784397399243
# m:2.46573502649634
# c:2.80615723706166
# Iteration : 215
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0201391515278150
# deltaE_c -0.100695757639075
# m:2.46593641801162
# c:2.80716419463805
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00258449526292170
# deltaE_c -0.00646123815730437
# m:2.46596226296425
# c:2.80722880701962
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0520836988789020
# deltaE_c 0.0868061647981699
# m:2.46544142597546
# c:2.80636074537164
# Iteration : 216
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0201101938866538
# deltaE_c -0.100550969433269
# m:2.46564252791433
# c:2.80736625506597
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00255069350731896
# deltaE_c -0.00637673376829762
# m:2.46566803484940
# c:2.80743002240365
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0520985059879768
# deltaE_c 0.0868308433132947
# m:2.46514704978952
# c:2.80656171397052
# Iteration : 217
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0200817752143149
# deltaE_c -0.100408876071574
# m:2.46534786754166
# c:2.80756580273124
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00251802010083901
# deltaE_c -0.00629505025209731
# m:2.46537304774267
# c:2.80762875323376
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0521115491276167
# deltaE_c 0.0868525818793611
# m:2.46485193225140
# c:2.80676022741496
# Iteration : 218
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0200538772269513
# deltaE_c -0.100269386134756
# m:2.46505247102366
# c:2.80776292127631
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00248643612568844
# deltaE_c -0.00621609031422121
# m:2.46507733538492
# c:2.80782508217945
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0521228900462449
# deltaE_c 0.0868714834104081
# m:2.46455610648446
# c:2.80695636734535
# Iteration : 219
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0200264822715516
# deltaE_c -0.100132411357758
# m:2.46475637130718
# c:2.80795769145893
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00245590400728046
# deltaE_c -0.00613976001820138
# m:2.46478093034725
# c:2.80801908905911
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0521325883604753
# deltaE_c 0.0868876472674591
# m:2.46425960446364
# c:2.80715021258644
# Iteration : 220
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0199995733041670
# deltaE_c -0.0999978665208352
# m:2.46445960019668
# c:2.80815019125164
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00242638746787271
# deltaE_c -0.00606596866968179
# m:2.46448386407136
# c:2.80821085093834
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0521407016286952
# deltaE_c 0.0869011693811590
# m:2.46396245705508
# c:2.80734183924453
# Iteration : 221
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0199731338688910
# deltaE_c -0.0998656693444548
# m:2.46416218839377
# c:2.80834049593797
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00239785148180771
# deltaE_c -0.00599462870451939
# m:2.46418616690858
# c:2.80840044222502
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0521472854221017
# deltaE_c 0.0869121423701698
# m:2.46366469405436
# c:2.80753132080132
# Iteration : 222
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0199471480775619
# deltaE_c -0.0997357403878096
# m:2.46386416553514
# c:2.80852867820520
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00237026223229941
# deltaE_c -0.00592565558074876
# m:2.46388786815746
# c:2.80858793476100
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0521523933932881
# deltaE_c 0.0869206556554802
# m:2.46336634422353
# c:2.80771872820445
# Iteration : 223
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0199216005901691
# deltaE_c -0.0996080029508457
# m:2.46356556022943
# c:2.80871480823396
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00234358706970816
# deltaE_c -0.00585896767427041
# m:2.46358899610013
# c:2.80877339791070
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0521560773424659
# deltaE_c 0.0869267955707764
# m:2.46306743532670
# c:2.80790412995499
# Iteration : 224
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0198964765959334
# deltaE_c -0.0994823829796672
# m:2.46326640009266
# c:2.80889895378479
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00231779447125846
# deltaE_c -0.00579448617814604
# m:2.46328957803737
# c:2.80895689864657
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0521583872813971
# deltaE_c 0.0869306454689953
# m:2.46276799416456
# c:2.80808759219188
# Iteration : 225
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0198717617950415
# deltaE_c -0.0993588089752073
# m:2.46296671178251
# c:2.80908118028163
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00229285400214496
# deltaE_c -0.00573213500536252
# m:2.46298964032253
# c:2.80913850163169
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0521593714951232
# deltaE_c 0.0869322858252053
# m:2.46246804660758
# c:2.80826917877343
# Iteration : 226
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0198474423810099
# deltaE_c -0.0992372119050491
# m:2.46266652103139
# c:2.80926155089248
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00226873627798341
# deltaE_c -0.00567184069495852
# m:2.46268920839417
# c:2.80931826929943
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0521590766015625
# deltaE_c 0.0869317943359373
# m:2.46216761762816
# c:2.80844895135608
# Iteration : 227
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0198235050236588
# deltaE_c -0.0991175251182939
# m:2.46236585267839
# c:2.80944012660726
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00224541292855385
# deltaE_c -0.00561353232138462
# m:2.46238830680768
# c:2.80949626193047
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0521575476090468
# deltaE_c 0.0869292460150781
# m:2.46186673133159
# c:2.80862696947032
# Iteration : 228
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0197999368526723
# deltaE_c -0.0989996842633616
# m:2.46206473070011
# c:2.80961696631295
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00222285656279997
# deltaE_c -0.00555714140699992
# m:2.46208695926574
# c:2.80967253772702
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0521548279718820
# deltaE_c 0.0869247132864697
# m:2.46156541098602
# c:2.80880329059416
# Iteration : 229
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0197767254417271
# deltaE_c -0.0988836272086355
# m:2.46176317824044
# c:2.80979212686625
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00220104073503102
# deltaE_c -0.00550260183757745
# m:2.46178518864779
# c:2.80984715288462
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0521509596439778
# deltaE_c 0.0869182660732966
# m:2.46126367905135
# c:2.80897797022389
# Iteration : 230
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0197538587931683
# deltaE_c -0.0987692939658413
# m:2.46146121763928
# c:2.80996566316355
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00217993991229593
# deltaE_c -0.00544984978073959
# m:2.46148301703841
# c:2.81002016166135
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0521459831306390
# deltaE_c 0.0869099718843982
# m:2.46096155720710
# c:2.80915106194251
# Iteration : 231
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0197313253232140
# deltaE_c -0.0986566266160698
# m:2.46115887046033
# c:2.81013762820867
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00215952944287823
# deltaE_c -0.00539882360719579
# m:2.46118046575476
# c:2.81019161644474
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0521399375385596
# deltaE_c 0.0868998958975995
# m:2.46065906637938
# c:2.80932261748577
# Iteration : 232
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0197091138476716
# deltaE_c -0.0985455692383579
# m:2.46085615751785
# c:2.81030807317815
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00213978552588356
# deltaE_c -0.00534946381470869
# m:2.46087755537311
# c:2.81036156781630
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0521328606240985
# deltaE_c 0.0868881010401639
# m:2.46035622676687
# c:2.80949268680590
# Iteration : 233
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0196872135681460
# deltaE_c -0.0984360678407299
# m:2.46055309890255
# c:2.81047704748430
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00212068518187047
# deltaE_c -0.00530171295467596
# m:2.46057430575437
# c:2.81053006461385
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0521247888398833
# deltaE_c 0.0868746480664724
# m:2.46005305786597
# c:2.80966131813319
# Iteration : 234
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0196656140587240
# deltaE_c -0.0983280702936202
# m:2.46024971400656
# c:2.81064459883612
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00210220622450197
# deltaE_c -0.00525551556125503
# m:2.46027073606880
# c:2.81069715399173
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0521157573798097
# deltaE_c 0.0868595956330163
# m:2.45974957849501
# c:2.80982855803540
# Iteration : 235
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0196443052531190
# deltaE_c -0.0982215262655948
# m:2.45994602154754
# c:2.81081077329806
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00208432723317009
# deltaE_c -0.00521081808292534
# m:2.45996686481987
# c:2.81086288147889
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0521058002224861
# deltaE_c 0.0868430003708101
# m:2.45944580681764
# c:2.80999445147518
# Iteration : 236
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0196232774322581
# deltaE_c -0.0981163871612902
# m:2.45964203959197
# c:2.81097561534679
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00206702752656773
# deltaE_c -0.00516756881641944
# m:2.45966270986723
# c:2.81102729103496
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0520949501731778
# deltaE_c 0.0868249169552966
# m:2.45914176036550
# c:2.81015904186540
# Iteration : 237
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0196025212122990
# deltaE_c -0.0980126060614950
# m:2.45933778557762
# c:2.81113916792602
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00205028713717215
# deltaE_c -0.00512571784293048
# m:2.45935828844899
# c:2.81119042510445
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0520832389043075
# deltaE_c 0.0868053981738459
# m:2.45883745605995
# c:2.81032237112271
# Iteration : 238
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0195820275330597
# deltaE_c -0.0979101376652984
# m:2.45903327633528
# c:2.81130147249936
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00203408678660910
# deltaE_c -0.00508521696652275
# m:2.45905361720315
# c:2.81135232466903
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0520706969945510
# deltaE_c 0.0867844949909182
# m:2.45853291023320
# c:2.81048447971912
# Iteration : 239
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0195617876468478
# deltaE_c -0.0978089382342389
# m:2.45872852810967
# c:2.81146256910146
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00201840786186747
# deltaE_c -0.00504601965466867
# m:2.45874871218829
# c:2.81151302929801
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0520573539665894
# deltaE_c 0.0867622566109825
# m:2.45822813864862
# c:2.81064540673190
# Iteration : 240
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0195417931076752
# deltaE_c -0.0977089655383758
# m:2.45842355657970
# c:2.81162249638728
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00200323239233446
# deltaE_c -0.00500808098083638
# m:2.45844358890362
# c:2.81167257719709
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0520432383235594
# deltaE_c 0.0867387305392660
# m:2.45792315652039
# c:2.81080518989170
# Iteration : 241
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0195220357608447
# deltaE_c -0.0976101788042230
# m:2.45811837687800
# c:2.81178129167974
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00198854302762408
# deltaE_c -0.00497135756905998
# m:2.45813826230827
# c:2.81183100525543
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0520283775842372
# deltaE_c 0.0867139626403954
# m:2.45761797853243
# c:2.81096386562903
# Iteration : 242
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0195025077328972
# deltaE_c -0.0975125386644859
# m:2.45781300360976
# c:2.81193899101567
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00197432301616951
# deltaE_c -0.00493580754042355
# m:2.45783274683992
# c:2.81198834909108
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0520127983170173
# deltaE_c 0.0866879971950292
# m:2.45731261885675
# c:2.81112146911913
# Iteration : 243
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0194832014219046
# deltaE_c -0.0974160071095231
# m:2.45750745087097
# c:2.81209562919022
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00196055618455593
# deltaE_c -0.00490139046138971
# m:2.45752705643282
# c:2.81214464309484
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0519965261727151
# deltaE_c 0.0866608769545252
# m:2.45700709117109
# c:2.81127803432529
# Iteration : 244
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0194641094880983
# deltaE_c -0.0973205474404915
# m:2.45720173226597
# c:2.81225123979970
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00194722691756666
# deltaE_c -0.00486806729391676
# m:2.45722120453514
# c:2.81229992047263
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0519795859162326
# deltaE_c 0.0866326431937212
# m:2.45670140867598
# c:2.81143359404070
# Iteration : 245
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0194452248448213
# deltaE_c -0.0972261242241061
# m:2.45689586092443
# c:2.81240585528294
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00193432013891570
# deltaE_c -0.00483580034728925
# m:2.45691520412582
# c:2.81245421328641
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0519620014571416
# deltaE_c 0.0866033357619029
# m:2.45639558411125
# c:2.81158817992879
# Iteration : 246
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0194265406497917
# deltaE_c -0.0971327032489584
# m:2.45658984951775
# c:2.81255950696128
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00192182129264795
# deltaE_c -0.00480455323162010
# m:2.45660906773067
# c:2.81260755249360
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0519437958792004
# deltaE_c 0.0865729931320010
# m:2.45608962977188
# c:2.81174182256228
# Iteration : 247
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0194080502966693
# deltaE_c -0.0970402514833464
# m:2.45628371027485
# c:2.81271222507711
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00190971632518000
# deltaE_c -0.00477429081295000
# m:2.45630280743810
# c:2.81275996798524
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0519249914688595
# deltaE_c 0.0865416524480995
# m:2.45578355752341
# c:2.81189455146076
# Iteration : 248
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0193897474069117
# deltaE_c -0.0969487370345581
# m:2.45597745499748
# c:2.81286403883111
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00189799166796112
# deltaE_c -0.00474497916990302
# m:2.45599643491416
# c:2.81291148862280
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0519056097427795
# deltaE_c 0.0865093495712994
# m:2.45547737881673
# c:2.81204639512709
# Iteration : 249
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0193716258219125
# deltaE_c -0.0968581291095627
# m:2.45567109507495
# c:2.81301497641819
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00188663422073310
# deltaE_c -0.00471658555183296
# m:2.45568996141716
# c:2.81306214227370
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0518856714743992
# deltaE_c 0.0864761191239989
# m:2.45517110470241
# c:2.81219738108246
# Iteration : 250
# ++++++++++++++++++++++++++++
# -->sample 1x=0.2y=3.4
# deltaE_m: -0.0193536795954105
# deltaE_c -0.0967683979770522
# m:2.45536464149837
# c:2.81316506506224
# -->sample 2x=0.4y=3.8
# deltaE_m: -0.00187563133536695
# deltaE_c -0.00468907833841747
# m:2.45538339781172
# c:2.81321195584562
# -->sample 3x=0.6y=4.2
# deltaE_m: 0.0518651967195911
# deltaE_c 0.0864419945326516
# m:2.45486474584453
# c:2.81234753590029
# ++++++++++++++++++++++++++++++++++++++
# Optimal Values:
# m:2.45486474584453
# c:2.81234753590029

# %%
#y =1.77x+0.99 --> BestFit Line
y_train_pred=[]
for i in range(0,len(x_train)):
  y_cal = mi*x_train['Bacteria_size'][i]+ci
  y_train_pred.append(y_cal)
y_train_pred
# Out:
# [3.30332048506920, 3.79429343423810, 4.28526638340701]

# %%
y_train_list = list(y_train['Max_Growth'])
y_train_list
# Out:
# [3.4, 3.8, 4.2]

# %%
Error=[]
for i in range(0,len(x_train)):
  err=(y_train_list[i]-y_train_pred[i])
  Error.append(err)
Error
# Out:
# [0.0966795149308020, 0.00570656576189688, -0.0852663834070082]

# %%
import matplotlib.pyplot as plt
plt.plot(x_train,y_train_list,label='y_train',color='blue')
plt.plot(x_train,y_train_pred,label='y_predicted',color='red')

plt.title('Visualising the Training Error')
plt.xlabel('x values')
plt.ylabel('y values')

plt.show()
